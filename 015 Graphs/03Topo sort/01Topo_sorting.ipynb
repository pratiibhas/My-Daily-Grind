# %%
def dfs(node, vis,st,adj):
    vis[node]=1
    for neigbor in adj[node]:
        if vis[neigbor] ==0:
            dfs(neigbor,vis,st,adj)
    st.append(node)   

def topo_sort(V,adj):
 
    vis=[0]*V
    st =[]
    for i in range(V):
        if not vis[i]:
            dfs(i,vis,st,adj)
    ans =[]
    while st:
        ans.append(st[-1])
        st.pop()
    return ans    
                
V = 6
# Adjacency list representation matching your C++ example:
adj = [
    [],         # 0
    [],         # 1
    [3],        # 2
    [1],        # 3
    [0, 1],     # 4
    [0, 2]      # 5
]

result = topo_sort(V, adj)
print("Topological order:", result)
# Out:
# Topological order: [5, 4, 2, 3, 1, 0]

# %%
def dfs(node, vis,st,adj):
    vis[node]=1
    for neigbor in adj[node]:
        if vis[neigbor] ==0:
            dfs(neigbor,vis,st,adj)
    st.append(node)   

def topo_sort(V,adj):
 
    vis=[0]*V
    st =[]
    for i in range(V):
        if not vis[i]:
            dfs(i,vis,st,adj)
    ans =[]
    return st[::-1]  
                
V = 6
# Adjacency list representation matching your C++ example:
adj = [
    [],         # 0
    [],         # 1
    [3],        # 2
    [1],        # 3
    [0, 1],     # 4
    [0, 2]      # 5
]

result = topo_sort(V, adj)
print("Topological order:", result)
# Out:
# Topological order: [5, 4, 2, 3, 1, 0]
